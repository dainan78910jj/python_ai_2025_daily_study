# %% [markdown]
# Lab: Set up the enviroments:
#
# Visit https://platform.openai.com/ and create an account and create a new API key.
# Download Cursor and install the program.
# After that you need to grab the API key from Openai and paste it in to Cursor.  (See todays lecture for details)
# When everything is set up. Create a website (portfolio) using Django.
# Try to do the same thing with Lovable in react for example. Just like i did the hello world in todays lecture.
# Visit n8n and create an account and set it up  and have it ready for future project.
#
# Good luck and dont hesitate to ask any questions you might have to me or Aladdin.
