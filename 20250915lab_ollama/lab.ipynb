# %% [markdown]
# Todays lab:
#
# Download Ollama, install it here by visiting https://ollama.com then pressing Download and following the instructions.
# After it's installed, you should be able to visit here: http://localhost:11434 and see the message "Ollama is running" .
# You might need to restart Cursor (and maybe reboot). Then open a Terminal (control+`) and run ollama serve
# Useful Ollama commands (run these in the terminal, or with an exclamation mark in this notebook):
# ollama pull <model_name> downloads a model locally
# ollama ls lists all the models you've downloaded
# ollama rm <model_name> deletes the specified model from your downloads
#
#
# Once that is setup then try to code along with me and compere the diffrent models to each other like i did in the lecture.
#
# (Optional lab or when you are done comparing):
# try this tutorial and maybe use Ollama instead of chatgpt like they say in the tutorial below.
# So basically create a chatbot using Ollama
# https://beebom.com/how-build-own-ai-chatbot-with-chatgpt-api/

# %%
# !ollama pull llama3.2
# Out:
# /usr/bin/sh: 1: ollama: not found

# %%
ollama = OpenAI(base_url='http://localhost:11434', api_key='ollama')

model_name = 'llama3.2'

messages=[
    {"role": "system", "content": "You are a helpful assistant."},
    {"role": "user", "content": "What is the capital of France?"}
]

response = ollama.chat.completions.create(
    model=model_name,
    messages=messages)

answer = response.choices[0].message.content

display(Markdown(answer))

competitors.append(model_name)
answers.append(answer)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 ollama = OpenAI(base_url='http://localhost:11434', api_key='ollama')
#       3 model_name = 'llama3.2'
#       5 messages=[
#       6     {"role": "system", "content": "You are a helpful assistant."},
#       7     {"role": "user", "content": "What is the capital of France?"}
#       8 ]
#
# NameError: name 'OpenAI' is not defined
