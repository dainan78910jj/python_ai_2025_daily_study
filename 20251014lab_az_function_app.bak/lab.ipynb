# %%
import requests
import json

# %%
with open("testdata.json") as f:
    data = json.load(f)

response = requests.post("http://localhost:7071/api/httppost", headers = {"Content-Type": "application/json"}, json = data)

print("Status", response.status_code)
print("Response", response.text)
